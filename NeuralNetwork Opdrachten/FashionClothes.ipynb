# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt

(train_data, train_labels), (test_data, test_labels) = fashion_mnist.load_data()

# %%
print("My train data Shape:", train_data.shape)
print("My train labels :", train_labels.shape)
print("Maximum label : ", train_labels.max())
# Out:
# My train data Shape: (60000, 28, 28)
# My train labels : (60000,)
# Maximum label :  9

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
index_of_choice = 100
plt.imshow(train_data[index_of_choice],cmap=plt.cm.binary)
plt.title(class_names[train_labels[index_of_choice]])
# Out:
# Text(0.5, 1.0, 'Bag')

# %%
model_1 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape= train_data[0].shape),
    tf.keras.layers.Dense(4, activation=tf.keras.activations.relu),
    tf.keras.layers.Dense(4, activation=tf.keras.activations.relu),
    tf.keras.layers.Dense(10, activation=tf.keras.activations.softmax)
])

model_1.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),
                optimizer = tf.keras.optimizers.Adam(),
                metrics = ["Accuracy"])

non_norm_history = model_1.fit(train_data,train_labels,epochs=10,validation_data=(test_data, test_labels))
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - Accuracy: 0.0990 - loss: 2.3472 - val_Accuracy: 0.0999 - val_loss: 2.3033
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.0977 - loss: 2.3028 - val_Accuracy: 0.1000 - val_loss: 2.3032
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.0988 - loss: 2.3028 - val_Accuracy: 0.1000 - val_loss: 2.3032
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.0996 - loss: 2.3028 - val_Accuracy: 0.1000 - val_loss: 2.3033
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.0977 - loss: 2.3028 - val_Accuracy: 0.1000 - val_loss: 2.3032
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - Accuracy: 0.0980 - loss: 2.3028 - val_Accuracy: 0.1000 - val_loss: 2.3032
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.0974 - loss: 2.3028 - val_Accuracy: 0.1000 - val_loss: 2.3032
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.0987 - loss: 2.3028 - val_Accuracy: 0.1000 - val_loss: 2.3032
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.0969 - loss: 2.3028 - val_Accuracy: 0.1000 - val_loss: 2.3032
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - Accuracy: 0.0989 - loss: 2.3028 - val_Accuracy: 0.1000 - val_loss: 2.3032

# %%
train_data_norm = train_data / 255.0
test_data_norm = test_data / 255.0

model_2 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape= train_data[0].shape),
    tf.keras.layers.Dense(4, activation=tf.keras.activations.relu),
    tf.keras.layers.Dense(4, activation=tf.keras.activations.relu),
    tf.keras.layers.Dense(10, activation=tf.keras.activations.softmax)
])

model_2.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),
                optimizer = tf.keras.optimizers.Adam(0.001),
                metrics = ["Accuracy"])

norm_history = model_2.fit(train_data_norm,train_labels,epochs=10,validation_data=(test_data_norm, test_labels))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - Accuracy: 0.4801 - loss: 1.2695 - val_Accuracy: 0.6335 - val_loss: 0.9531
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.6869 - loss: 0.8030 - val_Accuracy: 0.7228 - val_loss: 0.7574
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.7543 - loss: 0.6867 - val_Accuracy: 0.7477 - val_loss: 0.6888
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - Accuracy: 0.7714 - loss: 0.6348 - val_Accuracy: 0.7651 - val_loss: 0.6567
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - Accuracy: 0.7902 - loss: 0.6022 - val_Accuracy: 0.7809 - val_loss: 0.6267
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.7994 - loss: 0.5813 - val_Accuracy: 0.7846 - val_loss: 0.6190
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.8045 - loss: 0.5684 - val_Accuracy: 0.7926 - val_loss: 0.6026
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.8068 - loss: 0.5604 - val_Accuracy: 0.7906 - val_loss: 0.6125
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.8099 - loss: 0.5521 - val_Accuracy: 0.7906 - val_loss: 0.6115
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - Accuracy: 0.8112 - loss: 0.5477 - val_Accuracy: 0.7951 - val_loss: 0.6000

# %%
import random
def plot_random_image(model, images, true_labels, classes):
  i = random.randint(0, len(images))
  image_to_predict = images[i]
  true_positive_image = classes[true_labels[i]]
  pred_probs = model.predict(tf.expand_dims(image_to_predict, axis=0))
  predicted_image = classes[pred_probs.argmax()]
  
  plt.imshow(image_to_predict, cmap=plt.cm.binary)
  if(predicted_image == true_positive_image):
    color = "green"
  else:
    color = "red"

  plt.xlabel("Pred: {} {:2.0f}% (True: {})".format(predicted_image,
                                                    100*tf.reduce_max(pred_probs),
                                                    true_positive_image),color=color)
  
plot_random_image(model_2, test_data_norm, test_labels, class_names)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Exception in callback BaseAsyncIOLoop._handle_events()
# handle: <Handle BaseAsyncIOLoop._handle_events()>
# Traceback (most recent call last):
#   File "C:\Users\raymo\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 208, in _handle_events
#     handler_func(fileobj, events)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 600, in _handle_events
#     self._handle_recv()
#     ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 629, in _handle_recv
#     self._run_callback(callback, msg)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 550, in _run_callback
#     f = callback(*args, **kwargs)
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\ipykernel\iostream.py", line 105, in _handle_subscription
#     event_type = frame[0]
#                  ~~~~~^^^
# IndexError: index out of range
# Exception in callback BaseAsyncIOLoop._handle_events()
# handle: <Handle BaseAsyncIOLoop._handle_events()>
# Traceback (most recent call last):
#   File "C:\Users\raymo\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 208, in _handle_events
#     handler_func(fileobj, events)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 600, in _handle_events
#     self._handle_recv()
#     ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 629, in _handle_recv
#     self._run_callback(callback, msg)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 550, in _run_callback
#     f = callback(*args, **kwargs)
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\ipykernel\iostream.py", line 105, in _handle_subscription
#     event_type = frame[0]
#                  ~~~~~^^^
# IndexError: index out of range
# Exception in callback BaseAsyncIOLoop._handle_events()
# handle: <Handle BaseAsyncIOLoop._handle_events()>
# Traceback (most recent call last):
#   File "C:\Users\raymo\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 208, in _handle_events
#     handler_func(fileobj, events)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 600, in _handle_events
#     self._handle_recv()
#     ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 629, in _handle_recv
#     self._run_callback(callback, msg)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 550, in _run_callback
#     f = callback(*args, **kwargs)
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\ipykernel\iostream.py", line 105, in _handle_subscription
#     event_type = frame[0]
#                  ~~~~~^^^
# IndexError: index out of range
# Exception in callback BaseAsyncIOLoop._handle_events()
# handle: <Handle BaseAsyncIOLoop._handle_events()>
# Traceback (most recent call last):
#   File "C:\Users\raymo\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 208, in _handle_events
#     handler_func(fileobj, events)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 600, in _handle_events
#     self._handle_recv()
#     ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 629, in _handle_recv
#     self._run_callback(callback, msg)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 550, in _run_callback
#     f = callback(*args, **kwargs)
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\ipykernel\iostream.py", line 105, in _handle_subscription
#     event_type = frame[0]
#                  ~~~~~^^^
# IndexError: index out of range
# Exception in callback BaseAsyncIOLoop._handle_events()
# handle: <Handle BaseAsyncIOLoop._handle_events()>
# Traceback (most recent call last):
#   File "C:\Users\raymo\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 208, in _handle_events
#     handler_func(fileobj, events)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 600, in _handle_events
#     self._handle_recv()
#     ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 629, in _handle_recv
#     self._run_callback(callback, msg)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 550, in _run_callback
#     f = callback(*args, **kwargs)
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\ipykernel\iostream.py", line 105, in _handle_subscription
#     event_type = frame[0]
#                  ~~~~~^^^
# IndexError: index out of range
# Exception in callback BaseAsyncIOLoop._handle_events()
# handle: <Handle BaseAsyncIOLoop._handle_events()>
# Traceback (most recent call last):
#   File "C:\Users\raymo\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 208, in _handle_events
#     handler_func(fileobj, events)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 600, in _handle_events
#     self._handle_recv()
#     ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 629, in _handle_recv
#     self._run_callback(callback, msg)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 550, in _run_callback
#     f = callback(*args, **kwargs)
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\ipykernel\iostream.py", line 105, in _handle_subscription
#     event_type = frame[0]
#                  ~~~~~^^^
# IndexError: index out of range
# Exception in callback BaseAsyncIOLoop._handle_events()
# handle: <Handle BaseAsyncIOLoop._handle_events()>
# Traceback (most recent call last):
#   File "C:\Users\raymo\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 208, in _handle_events
#     handler_func(fileobj, events)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 600, in _handle_events
#     self._handle_recv()
#     ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 629, in _handle_recv
#     self._run_callback(callback, msg)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 550, in _run_callback
#     f = callback(*args, **kwargs)
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\ipykernel\iostream.py", line 105, in _handle_subscription
#     event_type = frame[0]
#                  ~~~~~^^^
# IndexError: index out of range
# Exception in callback BaseAsyncIOLoop._handle_events()
# handle: <Handle BaseAsyncIOLoop._handle_events()>
# Traceback (most recent call last):
#   File "C:\Users\raymo\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 208, in _handle_events
#     handler_func(fileobj, events)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 600, in _handle_events
#     self._handle_recv()
#     ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 629, in _handle_recv
#     self._run_callback(callback, msg)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 550, in _run_callback
#     f = callback(*args, **kwargs)
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\ipykernel\iostream.py", line 105, in _handle_subscription
#     event_type = frame[0]
#                  ~~~~~^^^
# IndexError: index out of range
# Exception in callback BaseAsyncIOLoop._handle_events()
# handle: <Handle BaseAsyncIOLoop._handle_events()>
# Traceback (most recent call last):
#   File "C:\Users\raymo\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 208, in _handle_events
#     handler_func(fileobj, events)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 600, in _handle_events
#     self._handle_recv()
#     ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 629, in _handle_recv
#     self._run_callback(callback, msg)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 550, in _run_callback
#     f = callback(*args, **kwargs)
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\ipykernel\iostream.py", line 105, in _handle_subscription
#     event_type = frame[0]
#                  ~~~~~^^^
# IndexError: index out of range
# Exception in callback BaseAsyncIOLoop._handle_events()
# handle: <Handle BaseAsyncIOLoop._handle_events()>
# Traceback (most recent call last):
#   File "C:\Users\raymo\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 208, in _handle_events
#     handler_func(fileobj, events)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 600, in _handle_events
#     self._handle_recv()
#     ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 629, in _handle_recv
#     self._run_callback(callback, msg)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 550, in _run_callback
#     f = callback(*args, **kwargs)
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\ipykernel\iostream.py", line 105, in _handle_subscription
#     event_type = frame[0]
#                  ~~~~~^^^
# IndexError: index out of range
# Exception in callback BaseAsyncIOLoop._handle_events()
# handle: <Handle BaseAsyncIOLoop._handle_events()>
# Traceback (most recent call last):
#   File "C:\Users\raymo\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 208, in _handle_events
#     handler_func(fileobj, events)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 600, in _handle_events
#     self._handle_recv()
#     ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 629, in _handle_recv
#     self._run_callback(callback, msg)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py", line 550, in _run_callback
#     f = callback(*args, **kwargs)
#   File "c:\Users\raymo\Documents\DEAI_portfolio\.venv\Lib\site-packages\ipykernel\iostream.py", line 105, in _handle_subscription
#     event_type = frame[0]
#                  ~~~~~^^^
# IndexError: index out of range
